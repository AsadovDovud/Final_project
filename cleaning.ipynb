# %% [markdown]
# <a href="https://colab.research.google.com/github/AsadovDovud/Final_project/blob/main/cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/automobile_data_nan.csv", index_col="index")
df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# 1                 four       111.0             21.0  16500.0
# 2                  six       154.0              NaN  16500.0
# 3                 four       102.0             24.0  13950.0
# 4                 five         NaN              NaN  17450.0

# %%
df.isnull()
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0        False       False       False   False        False             False
# 1        False       False        True   False        False             False
# 2        False       False       False   False        False             False
# 3        False       False       False   False        False             False
# 4        False       False       False   False        False             False
# ...        ...         ...         ...     ...          ...               ...
# 81       False       False       False   False        False             False
# 82       False       False        True   False         True             False
# 86       False       False       False    True        False             False
# 87       False       False       False   False         True             False
# 88       False       False       False   False        False             False
#
# ...

# %%
df.notnull()
# Out:
#        company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# index
# 0         True        True        True    True         True              True
# 1         True        True       False    True         True              True
# 2         True        True        True    True         True              True
# 3         True        True        True    True         True              True
# 4         True        True        True    True         True              True
# ...        ...         ...         ...     ...          ...               ...
# 81        True        True        True    True         True              True
# 82        True        True       False    True        False              True
# 86        True        True        True   False         True              True
# 87        True        True        True    True        False              True
# 88        True        True        True    True         True              True
#
# ...

# %%
df.isnull().sum()
# Out:
# company              0
# body-style           0
# wheel-base          15
# length              13
# engine-type         12
# num-of-cylinders     0
# horsepower          16
# average-mileage     15
# price                3
# dtype: int64

# %%
len(df)
# Out:
# 61

# %%
df.isnull().sum()/len(df)*100
# Out:
# company              0.000000
# body-style           0.000000
# wheel-base          24.590164
# length              21.311475
# engine-type         19.672131
# num-of-cylinders     0.000000
# horsepower          26.229508
# average-mileage     24.590164
# price                4.918033
# dtype: float64

# %%
df.dropna()
# Out:
#           company   body-style  wheel-base  length engine-type  \
# index
# 3            audi        sedan        99.8   176.6         ohc
# 5            audi        sedan        99.8   177.3         ohc
# 6            audi        wagon       105.8   192.7         ohc
# 17      chevrolet    hatchback        94.5   155.9         ohc
# 19          dodge    hatchback        93.7   157.3         ohc
# 28          honda        sedan        96.5   175.4         ohc
# 34         jaguar        sedan       113.0   199.6        dohc
# 37          mazda    hatchback        93.1   159.1         ohc
# 38          mazda    hatchback        93.1   159.1         ohc
# 54         nissan        sedan        94.5   165.3         ohc
# 56         nissan        wagon        94.5   170.2         ohc
# 62        porsche  convertible        89.5   168.9        ohcf
# 69         toyota        wagon        95.7   169.7         ohc
# 81     volkswagen        sedan        97.3   171.7         ohc
#
# ...

# %%
len(df.dropna())
# Out:
# 14

# %%
df.dropna(axis=1)
# Out:
#            company   body-style num-of-cylinders
# index
# 0      alfa-romero  convertible             four
# 1      alfa-romero  convertible             four
# 2      alfa-romero    hatchback              six
# 3             audi        sedan             four
# 4             audi        sedan             five
# ...            ...          ...              ...
# 81      volkswagen        sedan             four
# 82      volkswagen        sedan             four
# 86      volkswagen        sedan             four
# 87           volvo        sedan             four
# 88           volvo        wagon             four
#
# [61 rows x 3 columns]

# %%
df.dropna(axis=1, thresh=48)
# Out:
#            company   body-style  length engine-type num-of-cylinders    price
# index
# 0      alfa-romero  convertible   168.8        dohc             four  13495.0
# 1      alfa-romero  convertible   168.8        dohc             four  16500.0
# 2      alfa-romero    hatchback   171.2        ohcv              six  16500.0
# 3             audi        sedan   176.6         ohc             four  13950.0
# 4             audi        sedan   176.6         ohc             five  17450.0
# ...            ...          ...     ...         ...              ...      ...
# 81      volkswagen        sedan   171.7         ohc             four   7975.0
# 82      volkswagen        sedan   171.7         NaN             four   7995.0
# 86      volkswagen        sedan     NaN         ohc             four   9995.0
# 87           volvo        sedan   188.8         NaN             four  12940.0
# 88           volvo        wagon   188.8         ohc             four  13415.0
#
# [61 rows x 6 columns]

# %%
df.dropna(subset=['price', 'horsepower'])
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 1        alfa-romero  convertible         NaN   168.8        dohc
# 2        alfa-romero    hatchback        94.5   171.2        ohcv
# 3               audi        sedan        99.8   176.6         ohc
# 5               audi        sedan        99.8   177.3         ohc
# 6               audi        wagon       105.8   192.7         ohc
# 10               bmw        sedan         NaN   176.8         ohc
# 11               bmw        sedan       101.2   176.8         ohc
# 14               bmw        sedan       103.5     NaN         ohc
# 15               bmw        sedan       110.0   197.0         ohc
# 17         chevrolet    hatchback        94.5   155.9         ohc
# 18         chevrolet        sedan         NaN   158.8         ohc
# 19             dodge    hatchback        93.7   157.3         ohc
# 20             dodge    hatchback        93.7     NaN         ohc
# ...

# %% [markdown]
# ### 1 method
# Filling disappeared values with 0

# %%
df.fillna(0)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         0.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         0.0   171.7           0
# 86      volkswagen        sedan        97.3     0.0         ohc
# 87           volvo        sedan       104.3   188.8           0
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         0.0             21.0  13495.0
# ...

# %% [markdown]
# ### Filling missed walues based on columns not a whole

# %%
df.fillna({'horspower':100, 'wheel-base':90})
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        90.0   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        90.0   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# ...

# %%
df.fillna({'horsepower':np.mean(df['horsepower'])})
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four  108.266667             21.0  13495.0
# ...

# %% [markdown]
# ### Filling missed values with forward values (ffill) or back values (bfill)

# %%
df.fillna(method='ffill')
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         NaN             21.0  13495.0
# ...

# %%
df.fillna(method='bfill')
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        94.5   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   188.8         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four       111.0             21.0  13495.0
# ...

# %%
df[df.company=='toyota'].fillna(method='bfill')
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66           62.0             35.0   5348.0
# 67           62.0             31.0   6338.0
# 68           62.0             31.0   6488.0
# 69           62.0             31.0   6918.0
# 70           62.0             27.0   7898.0
# 71          156.0             27.0   8778.0
# 79          156.0              NaN  15750.0

# %%
df.fillna(df.mean()) #numeric_only=True
# Out:
# <ipython-input-153-efcfe6e29a7c>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean()) #numeric_only=True
#            company   body-style  wheel-base      length engine-type  \
# index
# 0      alfa-romero  convertible   88.600000  168.800000        dohc
# 1      alfa-romero  convertible   99.219565  168.800000        dohc
# 2      alfa-romero    hatchback   94.500000  171.200000        ohcv
# 3             audi        sedan   99.800000  176.600000         ohc
# 4             audi        sedan   99.400000  176.600000         ohc
# ...            ...          ...         ...         ...         ...
# 81      volkswagen        sedan   97.300000  171.700000         ohc
# 82      volkswagen        sedan   99.219565  171.700000         NaN
# ...

# %%
dfh = df[df['body-style']=='hatchback']
dfh
# Out:
#            company body-style  wheel-base  length engine-type  \
# index
# 2      alfa-romero  hatchback        94.5   171.2        ohcv
# 16       chevrolet  hatchback        88.4   141.1           l
# 17       chevrolet  hatchback        94.5   155.9         ohc
# 19           dodge  hatchback        93.7   157.3         ohc
# 20           dodge  hatchback        93.7     NaN         ohc
# 36           mazda  hatchback        93.1   159.1         NaN
# 37           mazda  hatchback        93.1   159.1         ohc
# 38           mazda  hatchback        93.1   159.1         ohc
# 39           mazda  hatchback         NaN     NaN         NaN
# 49      mitsubishi  hatchback         NaN   157.3         ohc
# 50      mitsubishi  hatchback        93.7     NaN         NaN
# 63         porsche  hatchback        98.4   175.7       dohcv
# 66          toyota  hatchback         NaN   158.7         ohc
# 67          toyota  hatchback        95.7   158.7         NaN
# ...

# %%
dfh.fillna(dfh.mean())
# Out:
# <ipython-input-155-ecf55eda71e8>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfh.fillna(dfh.mean())
#            company body-style  wheel-base   length engine-type  \
# index
# 2      alfa-romero  hatchback   94.500000  171.200        ohcv
# 16       chevrolet  hatchback   88.400000  141.100           l
# 17       chevrolet  hatchback   94.500000  155.900         ohc
# 19           dodge  hatchback   93.700000  157.300         ohc
# 20           dodge  hatchback   93.700000  159.325         ohc
# 36           mazda  hatchback   93.100000  159.100         NaN
# 37           mazda  hatchback   93.100000  159.100         ohc
# 38           mazda  hatchback   93.100000  159.100         ohc
# ...

# %% [markdown]
# ### .map() and .apply()

# %% [markdown]
# This method applies a function that accepts and returns a scalar to every element of a DataFrame.

# %%
df['num-of-cylinders'].unique()
# Out:
# array(['four', 'six', 'five', 'three', 'twelve', 'two', 'eight'],
#       dtype=object)

# %%
dict = {'two':2, 'three':3, 'four':4, 'five':5, 'six':6, 'eight':8, 'twelve':12}
df['cylinders'] = df['num-of-cylinders'].map(dict)
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders
# index
# 0                 four         NaN             21.0  13495.0          4
# ...

# %%
kurs = 10720
df['price_uz'] = df['price'].map(lambda x: x*kurs)
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders  \
# index
# 0                 four         NaN             21.0  13495.0          4
# ...

# %% [markdown]
# ### .replace() and .rename()

# %%
df.replace('four',4)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible         NaN   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan         NaN   171.7         NaN
# 86      volkswagen        sedan        97.3     NaN         ohc
# 87           volvo        sedan       104.3   188.8         NaN
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price  cylinders  \
# index
# 0                    4         NaN             21.0  13495.0          4
# ...

# %%
df2 = pd.read_csv("/content/world_population_duplicates.csv", index_col = 'country')

# %%
df2.rename(index=str.upper)
# Out:
#                   rank     density   densityMi    pop2021     area
# country
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# BURUNDI             28    440.3044   1140.3884  12255.433    27834
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# ...                ...         ...         ...        ...      ...
# NAMIBIA            228      3.1338      8.1166   2587.344   825615
# WESTERN SAHARA     229      2.3003      5.9577    611.875   266000
# MONGOLIA           230      2.1286      5.5129   3329.289  1564110
# FALKLAND ISLANDS   231      0.2902      0.7517      3.533    12173
# GREENLAND          232      0.0263      0.0680     56.877  2166086
#
# [247 rows x 5 columns]

# %%
df2.rename(columns=str.upper)
# Out:
#                   RANK     DENSITY   DENSITYMI    POP2021     AREA
# country
# Macau                1  21946.4667  56841.3487    658.394       30
# Monaco               2  19755.5000  51166.7450     39.511        2
# Burundi             28    440.3044   1140.3884  12255.433    27834
# Macau                1  21946.4667  56841.3487    658.394       30
# Monaco               2  19755.5000  51166.7450     39.511        2
# ...                ...         ...         ...        ...      ...
# Namibia            228      3.1338      8.1166   2587.344   825615
# Western Sahara     229      2.3003      5.9577    611.875   266000
# Mongolia           230      2.1286      5.5129   3329.289  1564110
# Falkland Islands   231      0.2902      0.7517      3.533    12173
# Greenland          232      0.0263      0.0680     56.877  2166086
#
# [247 rows x 5 columns]

# %%
df2.rename(index=str.upper, columns=str.upper)
# Out:
#                   RANK     DENSITY   DENSITYMI    POP2021     AREA
# country
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# BURUNDI             28    440.3044   1140.3884  12255.433    27834
# MACAU                1  21946.4667  56841.3487    658.394       30
# MONACO               2  19755.5000  51166.7450     39.511        2
# ...                ...         ...         ...        ...      ...
# NAMIBIA            228      3.1338      8.1166   2587.344   825615
# WESTERN SAHARA     229      2.3003      5.9577    611.875   266000
# MONGOLIA           230      2.1286      5.5129   3329.289  1564110
# FALKLAND ISLANDS   231      0.2902      0.7517      3.533    12173
# GREENLAND          232      0.0263      0.0680     56.877  2166086
#
# [247 rows x 5 columns]

# %%
df2.rename(columns={'pop2021':'population'}, index={'Macau':'Makao'})
# Out:
#                   rank     density   densityMi  population     area
# country
# Makao                1  21946.4667  56841.3487     658.394       30
# Monaco               2  19755.5000  51166.7450      39.511        2
# Burundi             28    440.3044   1140.3884   12255.433    27834
# Makao                1  21946.4667  56841.3487     658.394       30
# Monaco               2  19755.5000  51166.7450      39.511        2
# ...                ...         ...         ...         ...      ...
# Namibia            228      3.1338      8.1166    2587.344   825615
# Western Sahara     229      2.3003      5.9577     611.875   266000
# Mongolia           230      2.1286      5.5129    3329.289  1564110
# Falkland Islands   231      0.2902      0.7517       3.533    12173
# Greenland          232      0.0263      0.0680      56.877  2166086
#
# [247 rows x 5 columns]

# %% [markdown]
# ### Dublicate

# %% [markdown]
# <p>Return boolean values in a series

# %%
df2.duplicated()
# Out:
# country
# Macau               False
# Monaco              False
# Burundi             False
# Macau                True
# Monaco               True
#                     ...
# Namibia             False
# Western Sahara      False
# Mongolia            False
# Falkland Islands    False
# Greenland           False
# Length: 247, dtype: bool

# %%
df2.duplicated().sum()
# Out:
# 15

# %% [markdown]
# **drop_duplicates()**
# Deleting dublicate values

# %%
df2.drop_duplicates()
# Out:
#                   rank     density   densityMi    pop2021     area
# country
# Macau                1  21946.4667  56841.3487    658.394       30
# Monaco               2  19755.5000  51166.7450     39.511        2
# Burundi             28    440.3044   1140.3884  12255.433    27834
# Singapore            3   8305.1915  21510.4461   5896.686      710
# Hong Kong            4   6841.3134  17719.0017   7552.810     1104
# ...                ...         ...         ...        ...      ...
# Namibia            228      3.1338      8.1166   2587.344   825615
# Western Sahara     229      2.3003      5.9577    611.875   266000
# Mongolia           230      2.1286      5.5129   3329.289  1564110
# Falkland Islands   231      0.2902      0.7517      3.533    12173
# Greenland          232      0.0263      0.0680     56.877  2166086
#
# [232 rows x 5 columns]

# %% [markdown]
# for finding dublicates not from whole csv but only from mentioned row

# %%
df2.drop_duplicates(['rank'])
# Out:
#                   rank     density   densityMi    pop2021     area
# country
# Macau                1  21946.4667  56841.3487    658.394       30
# Monaco               2  19755.5000  51166.7450     39.511        2
# Burundi             28    440.3044   1140.3884  12255.433    27834
# Singapore            3   8305.1915  21510.4461   5896.686      710
# Hong Kong            4   6841.3134  17719.0017   7552.810     1104
# ...                ...         ...         ...        ...      ...
# Namibia            228      3.1338      8.1166   2587.344   825615
# Western Sahara     229      2.3003      5.9577    611.875   266000
# Mongolia           230      2.1286      5.5129   3329.289  1564110
# Falkland Islands   231      0.2902      0.7517      3.533    12173
# Greenland          232      0.0263      0.0680     56.877  2166086
#
# [232 rows x 5 columns]

# %% [markdown]
# ### Guruhlash

# %%
df3 = pd.read_csv('/content/world_population.csv', usecols=['country','pop2021', 'area'], index_col='country')
df3
# Out:
#                    pop2021     area
# country
# Macau              658.394       30
# Monaco              39.511        2
# Singapore         5896.686      710
# Hong Kong         7552.810     1104
# Gibraltar           33.698        6
# ...                    ...      ...
# Namibia           2587.344   825615
# Western Sahara     611.875   266000
# Mongolia          3329.289  1564110
# Falkland Islands     3.533    12173
# Greenland           56.877  2166086
#
# [232 rows x 2 columns]

# %% [markdown]
# **pandas.cut(x, bins, right=True, labels=None, retbins=False, precision=3, include_lowest=False, duplicates='raise', ordered=True)**

# %%
bins = [0, 1000, 10000, 30000, 50000, 100000, 300000, 1500000]

# %%
population = df3.pop2021

# %% [markdown]
# Use cut when you need to segment and sort data values into bins. This function is also useful for going from a continuous variable to a categorical variable. For example, cut could convert ages to groups of age ranges. Supports binning into an equal number of bins, or a pre-specified array of bins.

# %%
oraliq = pd.cut(population,bins)
oraliq
# Out:
# country
# Macau                   (0, 1000]
# Monaco                  (0, 1000]
# Singapore           (1000, 10000]
# Hong Kong           (1000, 10000]
# Gibraltar               (0, 1000]
#                         ...
# Namibia             (1000, 10000]
# Western Sahara          (0, 1000]
# Mongolia            (1000, 10000]
# Falkland Islands        (0, 1000]
# Greenland               (0, 1000]
# Name: pop2021, Length: 232, dtype: category
# Categories (7, interval[int64, right]): [(0, 1000] < (1000, 10000] < (10000, 30000] <
#                                          (30000, 50000] < (50000, 100000] < (100000, 300000] <
#                                          (300000, 1500000]]

# %%
oraliq.value_counts()
# Out:
# (0, 1000]            72
# (1000, 10000]        68
# (10000, 30000]       44
# (30000, 50000]       19
# (50000, 100000]      15
# (100000, 300000]     11
# (300000, 1500000]     3
# Name: pop2021, dtype: int64

# %%
df['popBins'] = oraliq

# %%
df4 = pd.read_csv('/content/automobile_data.csv', index_col='index')

# %%
bins = [0, 10000, 20000, 50000]

# %%
range = pd.cut(df.price, bins)

# %%
range.value_counts()
# Out:
# (0, 10000]        28
# (10000, 20000]    17
# (20000, 50000]    13
# Name: price, dtype: int64

# %%
groups = ["arzon", "o'rta", "qimmat"]
range = pd.cut(df.price, bins, labels=groups)
range.value_counts()
# Out:
# arzon     28
# o'rta     17
# qimmat    13
# Name: price, dtype: int64

# %%
range = pd.cut(df.price, 3)
range.value_counts()
# Out:
# (5110.751, 18567.333]     44
# (31983.667, 45400.0]       9
# (18567.333, 31983.667]     5
# Name: price, dtype: int64

# %%
range = pd.cut(df.price, 4)
range.value_counts()
# Out:
# (5110.751, 15213.25]    36
# (15213.25, 25275.5]     10
# (35337.75, 45400.0]      7
# (25275.5, 35337.75]      5
# Name: price, dtype: int64

# %% [markdown]
# **pandas.qcut(x, q, labels=None, retbins=False, precision=3, duplicates='raise')**
# Quantile-based discretization function.
#
# Discretize variable into equal-sized buckets based on rank or based on sample quantiles. For example 1000 values for 10 quantiles would produce a Categorical object indicating quantile membership for each data point.

# %%
range = pd.qcut(df.price, 3)
range.value_counts()
# Out:
# (5150.999, 7295.0]    20
# (7295.0, 16430.0]     19
# (16430.0, 45400.0]    19
# Name: price, dtype: int64

# %%
range = pd.qcut(df.horsepower, 3)
range.value_counts()
# Out:
# (51.999, 70.0]    18
# (112.0, 262.0]    15
# (70.0, 112.0]     12
# Name: horsepower, dtype: int64

# %% [markdown]
# ### .groupby()

# %%
df4.groupby('company').mean()
# Out:
# <ipython-input-184-4bc838971b82>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df4.groupby('company').mean()
#                wheel-base      length  horsepower  average-mileage  \
# company
# alfa-romero     90.566667  169.600000  125.333333        20.333333
# audi           101.200000  180.800000  109.250000        20.000000
# bmw            103.433333  185.033333  144.833333        19.000000
# chevrolet       92.466667  151.933333   62.666667        41.000000
# dodge           93.700000  157.300000   68.000000        31.000000
# honda           96.500000  167.200000   92.333333        26.333333
# isuzu           94.433333  160.833333   72.666667        33.333333
# jaguar         109.333333  196.966667  204.666667        14.333333
# ...

# %%
df4.groupby('company').price.mean()
# Out:
# company
# alfa-romero      15498.333333
# audi             16392.500000
# bmw              27213.333333
# chevrolet         6007.000000
# dodge             6303.000000
# honda            10195.000000
# isuzu             6785.000000
# jaguar           34600.000000
# mazda             9654.800000
# mercedes-benz    35040.000000
# mitsubishi        6689.000000
# nissan            8289.000000
# porsche          35528.000000
# toyota            8216.857143
# volkswagen        8435.000000
# volvo            13177.500000
# Name: price, dtype: float64

# %%
df.groupby(['company','body-style']).mean()
# Out:
# <ipython-input-186-22666974c88d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['company','body-style']).mean()
#                            wheel-base      length  horsepower  \
# company       body-style
# alfa-romero   convertible   88.600000  168.800000  111.000000
#               hatchback     94.500000  171.200000  154.000000
# audi          sedan         99.666667  176.833333  106.000000
#               wagon        105.800000  192.700000  110.000000
# bmw           sedan        103.880000  184.900000  146.500000
# chevrolet     hatchback     91.450000  148.500000   70.000000
#               sedan               NaN  158.800000   70.000000
# dodge         hatchback     93.700000  157.300000   68.000000
# honda         sedan         96.500000  172.250000  101.000000
# ...

# %%
df4.groupby('company').agg([min, max, np.mean])
# Out:
# <ipython-input-187-9addc5080843>:1: FutureWarning: ['body-style', 'engine-type', 'num-of-cylinders'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df4.groupby('company').agg([min, max, np.mean])
#               wheel-base                    length                     \
#                      min    max        mean    min    max        mean
# company
# alfa-romero         88.6   94.5   90.566667  168.8  171.2  169.600000
# audi                99.4  105.8  101.200000  176.6  192.7  180.800000
# bmw                101.2  110.0  103.433333  176.8  197.0  185.033333
# chevrolet           88.4   94.5   92.466667  141.1  158.8  151.933333
# dodge               93.7   93.7   93.700000  157.3  157.3  157.300000
# honda               96.5   96.5   96.500000  157.1  175.4  167.200000
# isuzu               94.3   94.5   94.433333  155.9  170.7  160.833333
# ...

# %%
df4.groupby('company').agg([min, max, lambda x: np.median(x)])
# Out:
# <ipython-input-188-9f04783163df>:1: FutureWarning: ['body-style', 'engine-type', 'num-of-cylinders'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df4.groupby('company').agg([min, max, lambda x: np.median(x)])
#               wheel-base                   length                    \
#                      min    max <lambda_0>    min    max <lambda_0>
# company
# alfa-romero         88.6   94.5      88.60  168.8  171.2     168.80
# audi                99.4  105.8      99.80  176.6  192.7     176.95
# bmw                101.2  110.0     102.35  176.8  197.0     182.90
# chevrolet           88.4   94.5      94.50  141.1  158.8     155.90
# dodge               93.7   93.7      93.70  157.3  157.3     157.30
# honda               96.5   96.5      96.50  157.1  175.4     169.10
# isuzu               94.3   94.5      94.50  155.9  170.7     155.90
# ...
